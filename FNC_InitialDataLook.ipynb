# %% [markdown]
# # Fake News Corpus

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %% [markdown]
# ### Downloading the data
# The file "FNC_Subset.csv" is a 10,000 line subset of the full data set. The full dataset is too large to put on GitHub. To download the full dataset:
#
# 1) Click on https://storage.googleapis.com/researchably-fake-news-recognition/news_cleaned_2018_02_13.csv.zip to download the zipped Fake News Corpus (about 10GB)
#
# 2) Unzip the file into the 'Data' subfolder.
#
# The code below should now work!

# %% [markdown]
# ### Initial Data Look

# %%
FNC_subset = pd.read_csv('data/news_cleaned_2018_02_13.csv', nrows=10000)
FNC_subset[:51]
# Out:
#     Unnamed: 0  id                 domain        type  \
# 0            0   2          express.co.uk       rumor
# 1            1   6     barenakedislam.com        hate
# 2            2   7     barenakedislam.com        hate
# 3            3   8     barenakedislam.com        hate
# 4            4   9     barenakedislam.com        hate
# 5            5  10     barenakedislam.com        hate
# 6            6  11  blackagendareport.com  unreliable
# 7            7  13  blackagendareport.com  unreliable
# 8            8  14  blackagendareport.com  unreliable
# 9            9  15  blackagendareport.com  unreliable
# 10          10  17      blackgenocide.org  conspiracy
# 11          11  18      blackgenocide.org  conspiracy
# 12          12  19      blackgenocide.org  conspiracy
# 13          13  20      blackgenocide.org  conspiracy
# 14          14  21   bipartisanreport.com   clickbait
# 15          15  22       theshovel.com.au      satire
# ...

# %% [markdown]
# ### Write subset of the data to file

# %%
FNC_subset.to_csv('data/FNC_Subset.csv')
